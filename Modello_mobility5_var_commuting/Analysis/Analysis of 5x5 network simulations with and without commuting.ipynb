# %% [markdown]
# Analysis of 100 simulations results on a network of the five NYC boroughs without variations of the commuting matrix during the simulations, using in case 1 the SIRcompleto_cluster2 code and in case 2 the code developed.
# Here I present the results concerning the number of recovered in each borough at the end of the simulations, in order to visualize the differences in the pandemic spreading and incidence that can be enlighted from the two codes.
# Simulations have been performed with $R_0 = 3$.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.lines as mlines
import numpy as np
import statsmodels.api as ssm
import statsmodels.formula.api as smf
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
df_base = pd.read_csv("/home/claudia/Scrivania/Tesi NYC pandemic /Modello_mobility5_var_commuting/Analysis/Recovered_R0_3_basemodel.csv")
df_nomobility = pd.read_csv("/home/claudia/Scrivania/Tesi NYC pandemic /Modello_mobility5_var_commuting/Analysis/Recovered_novarcomm_R0_3.csv")


#calcolo la frazione di recovered in base alla popolazione totale di ogni borough
df_base['Manhattan'] = df_base['Manhattan'].div(1628706)
df_nomobility['Manhattan'] = df_nomobility['Manhattan'].div(1628706)

df_base['Bronx'] = df_base['Bronx'].div(1418207)
df_nomobility['Bronx'] = df_nomobility['Bronx'].div(1418207)

df_base['Brooklyn'] = df_base['Brooklyn'].div(2559903)
df_nomobility['Brooklyn'] = df_nomobility['Brooklyn'].div(2559903)

df_base['Queens'] = df_base['Queens'].div(2253858)
df_nomobility['Queens'] = df_nomobility['Queens'].div(2253858)

df_base['StatenIsland'] = df_base['StatenIsland'].div(476143)
df_nomobility['StatenIsland'] = df_nomobility['StatenIsland'].div(476143)

# %%
data = [ df_base['Manhattan'],df_nomobility['Manhattan'], df_base['Bronx'], df_nomobility['Bronx'], df_base['Brooklyn'],  df_nomobility['Brooklyn'], df_base['Queens'], df_nomobility['Queens'], df_base['StatenIsland'], df_nomobility['StatenIsland']]

# %%
fig = plt.figure(1, figsize = (18, 10))
ax = fig.add_subplot(111)
bp = ax.boxplot(data, patch_artist = True, vert = 1)

colors = ['orchid', 'orchid', 'orange', 'orange','red', 'red', 'royalblue', 'royalblue', 'forestgreen', 'forestgreen'] 
  
for patch, color in zip(bp['boxes'], colors): 
    patch.set_facecolor(color);
    
for whisker in bp['whiskers']: 
    whisker.set(color ='navy', linewidth = 2) 
    
for cap in bp['caps']: 
    cap.set(color ='black', linewidth = 2)

for median in bp['medians']: 
    median.set(color ='black',linewidth = 2) 
    
for flier in bp['fliers']: 
    flier.set(marker ='D', color ='black', alpha = 0.5) 
      
ax.set_xticklabels(['Manhattan: case 1', 'Manhattan: case 2', 'Bronx: case 1', 'Bronx: case 2', 'Brooklyn: case 1','Brooklyn: case 2', 'Queens: case 1', 'Queens: case 2 ', 'Staten Island: case 1', 'Staten Island: case 2'], rotation = 30, fontsize = 12) 
ax.set_ylabel('Fraction of the total population of recovered indivisuals', fontsize = 15)
plt.title("Comparison of the fractions of recovered individuals of 100 simulazions, R0 = 3, with the two different SIR codes", fontsize = 15) 
plt.grid()

# %% [markdown]
# The same comparison is made below, but with 100 simulations performed with $R_0 = 1.5$.

# %%
df_base2 = pd.read_csv("/home/claudia/Scrivania/Tesi NYC pandemic /Modello_mobility5_var_commuting/Analysis/Recovered_R0_1.5_basemodel.csv")
df_nomobility2 = pd.read_csv("/home/claudia/Scrivania/Tesi NYC pandemic /Modello_mobility5_var_commuting/Analysis/Recovered_novarcomm_R0_1.5.csv")


#calcolo la frazione di recovered in base alla popolazione totale di ogni borough
df_base2['Manhattan'] = df_base2['Manhattan'].div(1628706)
df_nomobility2['Manhattan'] = df_nomobility2['Manhattan'].div(1628706)

df_base2['Bronx'] = df_base2['Bronx'].div(1418207)
df_nomobility2['Bronx'] = df_nomobility2['Bronx'].div(1418207)

df_base2['Brooklyn'] = df_base2['Brooklyn'].div(2559903)
df_nomobility2['Brooklyn'] = df_nomobility2['Brooklyn'].div(2559903)

df_base2['Queens'] = df_base2['Queens'].div(2253858)
df_nomobility2['Queens'] = df_nomobility2['Queens'].div(2253858)

df_base2['StatenIsland'] = df_base2['StatenIsland'].div(476143)
df_nomobility2['StatenIsland'] = df_nomobility2['StatenIsland'].div(476143)

data2 = [ df_base2['Manhattan'],df_nomobility2['Manhattan'], df_base2['Bronx'], df_nomobility2['Bronx'], df_base2['Brooklyn'],  df_nomobility2['Brooklyn'], df_base2['Queens'], df_nomobility2['Queens'], df_base2['StatenIsland'], df_nomobility2['StatenIsland']]

# %%
fig2 = plt.figure(1, figsize = (18, 10))
ax2 = fig2.add_subplot(111)
bp2 = ax2.boxplot(data2, patch_artist = True, vert = 1)

colors = ['orchid', 'orchid', 'orange', 'orange','red', 'red', 'royalblue', 'royalblue', 'forestgreen', 'forestgreen'] 
  
for patch, color in zip(bp2['boxes'], colors): 
    patch.set_facecolor(color);
    
for whisker in bp2['whiskers']: 
    whisker.set(color ='navy', linewidth = 2) 
    
for cap in bp2['caps']: 
    cap.set(color ='black', linewidth = 2)

for median in bp2['medians']: 
    median.set(color ='black',linewidth = 2) 
    
for flier in bp2['fliers']: 
    flier.set(marker ='D', color ='black', alpha = 0.5) 
      
ax2.set_xticklabels(['Manhattan: case 1', 'Manhattan: case 2', 'Bronx: case 1', 'Bronx: case 2', 'Brooklyn: case 1','Brooklyn: case 2', 'Queens: case 1', 'Queens: case 2 ', 'Staten Island: case 1', 'Staten Island: case 2'], rotation = 30, fontsize = 12) 
ax2.set_ylabel('Fraction of the total population of recovered indivisuals', fontsize = 15)
plt.title("Comparison of the fractions of recovered individuals of 100 simulazions, R0 = 1.5, with the two different SIR codes", fontsize = 15) 
plt.grid()

# %% [markdown]
# Let's now perform the analysis of 100 simulations results on a network of the five NYC boroughs without variations of the commuting matrix (case 1), using in case 1 the SIRcompleto_cluster2 code and the results of the simulations with the variations of weekly commuting (case 2) performed with SIRcompleto_weekly_mobility.
# Here I present the results concerning the number of recovered in each borough at the end of the simulations, in order to visualize the differences in the pandemic spreading and incidence that can derive from the application or not of the governmental measures as far as the reduction of the mobility is concerned.
#
# In the table below, results refer to simulations performed with $R_0 = 3$.

# %%
df_commutingvar = pd.read_csv("/home/claudia/Scrivania/Tesi NYC pandemic /Modello_mobility5_var_commuting/Analysis/Recovered_commutingvar_R0_3.csv")

#calcolo la frazione di recovered in base alla popolazione totale di ogni borough
df_commutingvar['Manhattan'] = df_commutingvar['Manhattan'].div(1628706)
df_commutingvar['Bronx'] = df_commutingvar['Bronx'].div(1418207)
df_commutingvar['Brooklyn'] = df_commutingvar['Brooklyn'].div(2559903)
df_commutingvar['Queens'] = df_commutingvar['Queens'].div(2253858)
df_commutingvar['StatenIsland'] = df_commutingvar['StatenIsland'].div(476143)

data3 = [ df_base['Manhattan'],df_commutingvar['Manhattan'], df_base['Bronx'], df_commutingvar['Bronx'], df_base['Brooklyn'],  df_commutingvar['Brooklyn'], df_base['Queens'], df_commutingvar['Queens'], df_base['StatenIsland'], df_commutingvar['StatenIsland']]

# %%
fig3 = plt.figure(1, figsize = (18, 12))
ax3 = fig3.add_subplot(111)
bp3 = ax3.boxplot(data3, patch_artist = True, vert = 1)

colors = ['orchid', 'orchid', 'orange', 'orange','red', 'red', 'royalblue', 'royalblue', 'forestgreen', 'forestgreen'] 
  
for patch, color in zip(bp3['boxes'], colors): 
    patch.set_facecolor(color);
    
for whisker in bp3['whiskers']: 
    whisker.set(color ='navy', linewidth = 2) 
    
for cap in bp3['caps']: 
    cap.set(color ='black', linewidth = 2)

for median in bp3['medians']: 
    median.set(color ='black',linewidth = 2) 
    
for flier in bp3['fliers']: 
    flier.set(marker ='D', color ='black', alpha = 0.5) 
      
ax3.set_xticklabels(['Manhattan: case 1', 'Manhattan: case 2', 'Bronx: case 1', 'Bronx: case 2', 'Brooklyn: case 1','Brooklyn: case 2', 'Queens: case 1', 'Queens: case 2 ', 'Staten Island: case 1', 'Staten Island: case 2'], rotation = 30, fontsize = 12) 
ax3.set_ylabel('Fraction of the total population of recovered indivisuals', fontsize = 15)
plt.title("Comparison of the fractions of recovered individuals of 100 simulazions, R0 = 3, without (case 1) and with (case2) variations in commuting patterns", fontsize = 15) 
plt.grid()

# %% [markdown]
# Instead, in the table below, results refer to simulations performed with $R_0 = 1.5$.

# %%
df_commutingvar2 = pd.read_csv("/home/claudia/Scrivania/Tesi NYC pandemic /Modello_mobility5_var_commuting/Analysis/Recovered_commutingvar_R0_1.5.csv")

#calcolo la frazione di recovered in base alla popolazione totale di ogni borough
df_commutingvar2['Manhattan'] = df_commutingvar2['Manhattan'].div(1628706)
df_commutingvar2['Bronx'] = df_commutingvar2['Bronx'].div(1418207)
df_commutingvar2['Brooklyn'] = df_commutingvar2['Brooklyn'].div(2559903)
df_commutingvar2['Queens'] = df_commutingvar2['Queens'].div(2253858)
df_commutingvar2['StatenIsland'] = df_commutingvar2['StatenIsland'].div(476143)

data4 = [ df_base2['Manhattan'],df_commutingvar2['Manhattan'], df_base2['Bronx'], df_commutingvar2['Bronx'], df_base2['Brooklyn'],  df_commutingvar2['Brooklyn'], df_base2['Queens'], df_commutingvar2['Queens'], df_base2['StatenIsland'], df_commutingvar2['StatenIsland']]

# %%
fig4 = plt.figure(1, figsize = (18, 12))
ax4 = fig4.add_subplot(111)
bp4 = ax4.boxplot(data4, patch_artist = True, vert = 1)

colors = ['orchid', 'orchid', 'orange', 'orange','red', 'red', 'royalblue', 'royalblue', 'forestgreen', 'forestgreen'] 
  
for patch, color in zip(bp4['boxes'], colors): 
    patch.set_facecolor(color);
    
for whisker in bp4['whiskers']: 
    whisker.set(color ='navy', linewidth = 2) 
    
for cap in bp4['caps']: 
    cap.set(color ='black', linewidth = 2)

for median in bp4['medians']: 
    median.set(color ='black',linewidth = 2) 
    
for flier in bp4['fliers']: 
    flier.set(marker ='D', color ='black', alpha = 0.5) 
      
ax4.set_xticklabels(['Manhattan: case 1', 'Manhattan: case 2', 'Bronx: case 1', 'Bronx: case 2', 'Brooklyn: case 1','Brooklyn: case 2', 'Queens: case 1', 'Queens: case 2 ', 'Staten Island: case 1', 'Staten Island: case 2'], rotation = 30, fontsize = 12) 
ax4.set_ylabel('Fraction of the total population of recovered indivisuals', fontsize = 15)
plt.title("Comparison of the fractions of recovered individuals of 100 simulazions, R0 = 1.5, without (case 1) and with (case2) variations in commuting patterns", fontsize = 15) 
plt.grid()
